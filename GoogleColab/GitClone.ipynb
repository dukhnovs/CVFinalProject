# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd "drive/My Drive/Colab Notebooks/ComputerVision_FinalProject"

# !git clone https://github.com/andrewssobral/vehicle_detection_haarcascades.git
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Colab Notebooks/ComputerVision_FinalProject
# Cloning into 'vehicle_detection_haarcascades'...
# remote: Enumerating objects: 54, done.
# remote: Total 54 (delta 0), reused 0 (delta 0), pack-reused 54
# Unpacking objects: 100% (54/54), done.

# %%
ls
# Out:
# Hw4-grading.doc          Notes.gdoc   vehicle_detection_haarcascades/
# Hw4-report-template.doc  Start.ipynb  Videos/

# %%
# %cd "vehicle_detection_haarcascades"
# %ls
# !python "vehicle_detection.py"
# Out:
# [Errno 2] No such file or directory: 'vehicle_detection_haarcascades'
# /content/drive/My Drive/Colab Notebooks/ComputerVision_FinalProject/vehicle_detection_haarcascades
# build/          README.md                        vehicle_detection.cpp
# cars.xml        run_vehicle_detection.bat        vehicle_detection.py
# CMakeLists.txt  run_vehicle_detection_video1.sh  vs2013/
# dataset/        run_vehicle_detection_video2.sh
# 3.4.3
# : cannot connect to X server
